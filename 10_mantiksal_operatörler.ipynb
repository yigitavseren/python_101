# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#sayi = int(input('Bir sayı giriniz: '))

#kontrol = sayi<=100 and sayi > 0

#print(f'Uygun mu:{kontrol}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#sayi = int(input('Bir sayı giriniz: '))

#kontrol = sayi>0 and sayi%2 == 0

#print(f'Uygun mu:{kontrol}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#varemail = 'email@sadikturan.com'
#varparola = 'abc123'

#email = input('Bir email giriniz: ')
#parola = input('Bir parola giriniz: ')

#kontrol = varemail == email and varparola == parola

#print(f'Uygun:{kontrol}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#sayi1 = int(input('Bir sayı giriniz: '))
#sayi2 = int(input('Bir sayı giriniz: '))
#sayi3 = int(input('Bir sayı giriniz: '))

#kontrol = sayi1 > sayi2  and sayi1>sayi3

#print(f'En büyük sayı1:{kontrol}')

#kontrol2 = sayi2>sayi1 and sayi2>sayi3
#print(f'En büyük sayi2:{kontrol2}')

#kontrol3 = sayi3>sayi1 and sayi3>sayi2
#print(f'En büyük sayı3:{kontrol}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#vize1 = float(input('Vize 1 sonucunu giriniz: '))
#vize2 = float(input('Vize 2 sonucunu giriniz: '))
#final = float(input('final sonucunu giriniz: '))

#ortalama = (vize1 + vize2)*(60/100) + (final) * (40/100)

#kontrol = ortalama > 50 and final >= 50 #a şıkkı budur

#kontrol = ortalama > 50 or final >= 70 #b şıkkı budur


#print(f'Uygun:{kontrol}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#ad = input('Adınızı giriniz: ')
#kilo = float(input('Kilonuzu giriniz: '))
#boy = float(input('Boyunuzu giriniz: '))

#formül = (kilo)/(boy*boy)

#kontrol = 0<formül and formül<=18.4

#print(f'Zayıf:{kontrol}')

#kontrol2 = 18.5<formül and formül <= 24.9

#print(f'Normal:{kontrol2}')

#kontrol3 = 25.0<formül and formül <= 29.9

#print(f'Fazla Kilolu:{kontrol3}')
#
#kontrol4 = 30.0<formül and formül <= 34.9

#print(f'Şişman(Obez):{kontrol4}')
