# %%
#sayilar = [1,3,5,7,9,12,19,21]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#for sayi in sayilar: #şu trick güzel öğren bunu 
#    if(sayi % 3 == 0):
#        print(sayi)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#toplam = 0 #bunlar güzel örnekler kavramaya bak
#for sayi in sayilar:
#    toplam += sayi
#print(toplam)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#for sayi in sayilar:
#    if (sayi % 2 == 1):
#        print(sayi**2)

# %%
sehirler = ['kocaeli','istanbul','ankara','izmir','rize']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#for sehir in sehirler:
#    if (len(sehir) <= 5):
#        print(sehir)

# %%
urunler =[
    {'name':'samsung S6', 'price': '3000' },
    {'name':'samsung S7', 'price': '4000' },
    {'name':'samsung S8', 'price': '5000' },
    {'name':'samsung S9', 'price': '6000' },
    {'name':'samsung S10', 'price': '7000' },
]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#toplam = 0 #dikkatli ol
#for urun in urunler:
#    toplam += int(urun['price'])
#print(toplam)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#for urun in urunler: #kodun sonunu unutma
#    fiyat = int(urun['price'])
#    if (fiyat<=5000):
#        print(urun['name'])
#
