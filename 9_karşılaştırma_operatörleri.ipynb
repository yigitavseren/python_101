# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#sayi1 = int(input('Bir sayı giriniz: '))
#sayi2 = int(input('Bir sayı giriniz: '))

#result =( sayi1 > sayi2 )
#print(f'a:{sayi1} b:{sayi2} den büyüktür: {result}')#dikkat

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#vize1 = float(input('Vize 1 sonucunu giriniz: '))
#vize2 = float(input('Vize 2 sonucunu giriniz: '))
#final = float(input('final sonucunu giriniz: '))

#ortalama = (vize1 + vize2)*(60/100) + (final) * (40/100)

#print(f'Ortalamanız budur {ortalama} , geçme durumu {ortalama > 50}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#sayi = int(input('Bir sayı giriniz: '))

#print(f'Sayı tek mi {sayi%2 == 1} ,sayı çift mi {sayi%2 == 0}') #2 tane eşittir koymayı unutmaa

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#sayi = int(input('Bir sayı giriniz: '))

#print(f'Sayı {sayi<0} eksili bir sayıdır,Sayı {sayi>0} sayı pozitif bir sayıdır.')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#varemail = 'email@sadikturan.com'
#varparol = 'abc123'

#email = input('Bir email giriniz: ')
#parola = input('Bir parola giriniz: ')


#print(f'Email : {email == varemail},Parola : {parola == varparol}')
# Out:
# Email : True,Parola : True
