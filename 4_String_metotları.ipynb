# %% [markdown]
# ![image.png](attachment:image.png)

# %%
website = "http://www.sadikturan.com"
course = "Python Kursu: Baştan sona Python Programlama Rehberiniz (40 saat)"
example = ' Hello World '
print(example.strip())
print(example.lstrip())
print(example.rstrip())
# Out:
# Hello World
# Hello World
#  Hello World

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
example2 = "http://www.sadikturan.com"
print(example2.strip('w.moc'))
print(example2.lstrip('htp:/w.moc')) #biraz garip
# Out:
# http://www.sadikturan
# sadikturan.com

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(course.lower())
print(course.upper())
print(course.title())
# Out:
# python kursu: baştan sona python programlama rehberiniz (40 saat)
# PYTHON KURSU: BAŞTAN SONA PYTHON PROGRAMLAMA REHBERINIZ (40 SAAT)
# Python Kursu: Baştan Sona Python Programlama Rehberiniz (40 Saat)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(website.count('a'))
print(website.count('www'))
print(website.count('www',0,10)) #şu sondaki iki sayı 0 10 arası aratmamı sağladı
# Out:
# 2
# 1
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(website.startswith('www'))
print(website.endswith('com'))
# Out:
# False
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(website.find('.com'))#indeks numarasını döndürür
print(website.find('.com',0,10)) #bulamadığından -1 değerini döndürdü
print(course.find('Python')) #bu direkt soldan aramaya başladığı için 0 değerini döndürdü
print(course.rfind('Python')) #bu ise sağdan he

print(course.index('Python'))
print(course.index('Python')) #bu hata verir işte index ve find arasındaki fark budur bu normalde hatalı oluyor tekrar baktığında hatlı yaz ama alt kodlar etkileniyor hatalı olunca dikkat
# Out:
# 21
# -1
# 0
# 26
# 0
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(course.isalpha())
print(course.isdigit()) #bu ifade sayısal olup olmadığını söyler
# Out:
# False
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
example4 = 'Contents' 
print(example4.center(50,'*'))
print(example4.ljust(50,'*'))
print(example4.rjust(50,'*'))
# Out:
# *********************Contents*********************
# Contents******************************************
# ******************************************Contents

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(course.replace(' ','-'))
print(course.replace(' ','-',5)) #sadece 5 karakteri etki eder
print(course.replace(' ','')) #tüm boşlukları da sildirtebilirsin
# Out:
# Python-Kursu:-Baştan-sona-Python-Programlama-Rehberiniz-(40-saat)
# Python-Kursu:-Baştan-sona-Python-Programlama Rehberiniz (40 saat)
# PythonKursu:BaştansonaPythonProgramlamaRehberiniz(40saat)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('Hello World'.replace('World','There'))
# Out:
# Hello There

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(course.replace(' ',''))
print(course.split(' '))#ayırır
# Out:
# PythonKursu:BaştansonaPythonProgramlamaRehberiniz(40saat)
# ['Python', 'Kursu:', 'Baştan', 'sona', 'Python', 'Programlama', 'Rehberiniz', '(40', 'saat)']
