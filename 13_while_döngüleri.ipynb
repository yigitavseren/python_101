# %%
#sayilar = [1,3,5,7,9,12,19,21]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#i = 0 #kesinlikle aklıma gelmezdi öğren bunu hoş
#while (i < len(sayilar)):
#    print(sayilar[i])
#    i += 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#start = int(input('Bir başlangıç değeri giriniz: '))   #bak bu da garip sen çalış
#finish = int(input('Bir başlangıç değeri giriniz: '))

#i = start
#while i<finish:
#    i += 1
#    if (i %2 ==1):
#        print(i)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
##i=100
#while i>1:
#    i-=1
#    print(i)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#numbers = [] #çok zorr
#i=0
#while i<5:
#    sayi1 = int(input('Bir sayı giriniz: '))
#    numbers.append(sayi1)
#    i += 1
#numbers.sort()
#print(numbers2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#urunsay = int(input('Lütfen ürün gireceğiniz ürün adedini yazınız: ')) #mantıkkkk

#i=0
#while i < urunsay:
#    urunad = input('Ürün adı giriniz: ')
#    urunfiyat = input('Ürün fiyatı giriniz: ')
#    print(f'Name:{urunad},Price:{urunfiyat}')
#    i +=1
#
# Out:
# Name:Torku,Price:56
# Name:yumrta,Price:78
# Name:tablet,Price:100000000000
