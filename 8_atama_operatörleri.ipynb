# %%
x, y, z = 2, 5, 10

numbers = 1, 5, 7, 10, 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#sayi1 = input('Bir sayı giriniz: ')#
#sayi2 = input('Bir sayı giriniz: ')

#carpim = int(sayi1) * int(sayi2)

#toplam = x + y + z 

#print(carpim - toplam )

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#bolum = y / x

#print(int(bolum))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#cevap = (x + y + z)
#
#print(cevap%3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#cevap = y**x

#print(cevap)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#x, *y ,z = numbers #x başı y ortadaki bütün değerleri ve z sonu alır dikkat

#print(y)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#x, *y, z = numbers

#print(sum(y))
# Out:
# 22
