# %% [markdown]
# ![image.png](attachment:image.png)

# %%
musteri_adı = "Yiğit" #string'de çift tırnağı unutma baabalık
musteri_soyadi = "Avseren"
musteri_ad_soyad = musteri_adı + " " + musteri_soyadi #şuraya dikkat
musteri_cinsiyeti = "erkek"
musteri_tc_kimlik_no = 12321321321
musteri_dogum_yili =  2004
musteri_adres_bilgisi = "blabla"
musteri_yası = 20
print(musteri_ad_soyad)
# Out:
# Yiğit Avseren

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
siparis1 = 110
siparis2 = 1100.5
siparis3 = 356.95

siparis_toplam = siparis1 + siparis2 + siparis3

print("Toplam:",siparis_toplam)  #şu aradaki virgülü unutma
# Out:
# Toplam: 1567.45
