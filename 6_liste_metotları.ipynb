# %%
names = ["Ali","Yağmur","Okan","Deniz"]
years = [1998,2000,1998,1987]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#names.append('Cenk')
#print(names)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#names.insert(0,"Sena") #koyamya yarıyor süper
#print(names)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#names.remove("Deniz")
#print(names)
#names.pop() #bu fonksiyona bir şey yazmasan otomatik olarak dizinin en sonunu siler 1 versen 1 indekisni siler

#print(names)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#print(names.index("Deniz"))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#print("Ali" in names )

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#print(names[::-1])
#names.reverse() #bu da olur
#print(names)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#names.sort()
#print(names)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#years.sort()
#print(years)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#str = "Chevrolet ,Dacia"
#str.split(",") # değişik bak buna

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#min = min(years)
#max = max(years)
#print(min,max)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#print(years.count(1998))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#years.clear()
#print(years)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
markalar = []

marka = input("Marka: ")
markalar.append(marka)


marka = input("Marka: ")
markalar.append(marka)


marka = input("Marka: ")
markalar.append(marka)

print(markalar)
# Out:
# ['7', '9', '3']
