# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#isim = input('İsminizi giriniz: ')
#yas = int(input('Yaşınızı giriniz: '))
#egitimbilgisi = input('Eğitim bilginizi yazınız: ')

#if (yas>18):
#    if (egitimbilgisi == 'lise' or egitimbilgisi == 'üniversite'):
#        print(f'{isim} ehliyet almaya hak kazanmıştır.')
#    else:
#        print('Ehliyet alamazsınız.')
#else:
#    print("Ehlyet alamzsınız.")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#exam1 = int(input('Sınav notunuzu giriniz: '))
#exam2 = int(input('2.sınav sonucunuzu giriniz: '))
#speaking = int(input('Lütfen sözlünüzü giriniz: '))

#ortalama = (exam1 + exam2 + speaking)/3

#if (ortalama>0 and ortalama <= 24):
#    print('0 aldın yazık kafana.')
#if (ortalama>25 and ortalama <= 44):
#    print('1 aldın yazık kafana.')
#if (ortalama>45 and ortalama <= 54):
#    print('2 aldın yazık kafana.')
#if (ortalama>55 and ortalama <= 69):
#    print('3 aldın ortalama fena değil.')
#if (ortalama>70 and ortalama <= 84):
#    print('4 iyi lan.')        
#if (ortalama>85 and ortalama <= 100):
#    print('5 müthişsin.')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import datetime

tarih = input('aracınız hangi tarihte trafiğe çıktı (2019/8/9): ')
tarih = tarih.split('/')
