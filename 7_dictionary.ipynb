# %%
'''
ogrenciler = {
    '120' : {
        'ad' : 'Ali',
        'soyad' : 'Yılmaz',
        'telefon': '532 000 00 01'   
    },
    '125' : {
        'ad' : 'Can',
        'soyad' : 'Korkmaz',
        'telefon' : '532 000 00 02'
    },
    '128' : {
        'ad' : 'Volkan',
        'soyad' : 'Yükselen',
        'telefon' : '532 000 00 03'
    },
}
'''
# Out:
# "\nogrenciler = {\n    '120' : {\n        'ad' : 'Ali',\n        'soyad' : 'Yılmaz',\n        'telefon': '532 000 00 01'   \n    },\n    '125' : {\n        'ad' : 'Can',\n        'soyad' : 'Korkmaz',\n        'telefon' : '532 000 00 02'\n    },\n    '128' : {\n        'ad' : 'Volkan',\n        'soyad' : 'Yükselen',\n        'telefon' : '532 000 00 03'\n    },\n}\n"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#ogrenciler = {}

#number = input("Öğrenci no: ")
#name = input("Öğrenci adı: ")
#surnmame = input("Öğrenci Soyadı ")
#phone = input("Öğrenci telefon: ")

#ogrenciler[number] = {
##    'ad' : name,
#    'soyad' : surnmame,
#    'telefon' : phone,
#}
#print(ogrenciler)

#update fonksiyonu ile de aynı şeyi yapabilirsin hatta daha fazla öğrenci bile tutabilirsin
# Out:
# {'131': {'ad': 'Mahmut', 'soyad': 'Aga', 'telefon': '0000000000'}}
