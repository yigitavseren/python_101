# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arabalar = ["Bmw","Mercedes","Opel","Mazda"]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(len(arabalar))
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(arabalar[0])
print(arabalar[3])
print(arabalar[-1])
# Out:
# Bmw
# Mazda
# Mazda

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arabalar[-1] = 'Toyota'
print(arabalar[-1])
# Out:
# Toyota

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('Mercedes' in arabalar)
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(arabalar[-2])
# Out:
# Opel

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(arabalar[0:3])
print(arabalar[:3])
print(arabalar[-3:])
# Out:
# ['Bmw', 'Mercedes', 'Opel']
# ['Bmw', 'Mercedes', 'Opel']
# ['Mercedes', 'Opel', 'Toyota']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arabalar[-2:]=["Toyota","Renault"]
print(arabalar)
# Out:
# ['Bmw', 'Mercedes', 'Toyota', 'Renault']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(arabalar + ["Audi","Nissan"])
# Out:
# ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi', 'Nissan']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
del arabalar[-1]
print(arabalar)
# Out:
# ['Bmw', 'Mercedes', 'Toyota']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(arabalar[::-1])
# Out:
# ['Toyota', 'Mercedes', 'Bmw']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
studentA = ["Yiğit" , "Bilgi",2010,[70,60,70]] #liste içerisinde liste sakladık
studentB = ["Sena Turan",1999,[80,80,70]]
studentC = ["Ahmet Turan",1998,[80,70,90]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(f"Adı ve soyadı {studentA[0]} {studentA[1]} bu olan öğrenci , {2024 - studentA[2]} yaşındadır ve notlarının ortalaması {studentA[3][0]+studentA[3][1]+studentA[3][2]/3} budur .  ")
# Out:
# Adı ve soyadı Yiğit Bilgi bu olan öğrenci , 14 yaşındadır ve notlarının ortalaması 153.33333333333334 budur .
